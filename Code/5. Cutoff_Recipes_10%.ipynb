# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
recipe_sm = pd.read_csv("D:/IIITD/Mansi_Thesis_Research/Foodprint/Carbon_Footprint_July23/Data/RecipeCF/RecipeDB_CF_with_string_matching.csv")
recipe_sm
# Out:
#         Recipe ID                        Recipe Name  \
# 0            2610               Egyptian Lentil Soup
# 1            2611  Egyptian Green Beans with Carrots
# 2            2612                     Egyptian Bamia
# 3            2613        Magpie's Easy Falafel Cakes
# 4            2614                             Dukkah
# ...           ...                                ...
# 118078     149187       Jerusalem Artichoke Stir Fry
# 118079     149188           Asian Apple Pear Compote
# 118080     149189             Skillet Sweet Potatoes
# 118081     149190                Any-Flavour Cookies
# 118082     149191        Fig Newton " Sarah - Bars "
#
#                                         Recipe Ingredient  Total Ingredient  \
# 0       ['black pepper', 'cumin', 'garlic', 'sea salt'...                10
# 1       ['green bean carrot', 'vegetable oil', 'bay le...                 9
# 2       ['okra', 'salt black pepper', 'lamb shoulder',...                 7
# ...

# %%
# Select recipes having available percentage coverage greater than or equal to 10 

recipesm_cutoff_10 = recipe_sm[recipe_sm['Available Percentage'] >= 10.000000]
recipesm_cutoff_10
# Out:
#         Recipe ID                        Recipe Name  \
# 0            2610               Egyptian Lentil Soup
# 1            2611  Egyptian Green Beans with Carrots
# 2            2612                     Egyptian Bamia
# 3            2613        Magpie's Easy Falafel Cakes
# 4            2614                             Dukkah
# ...           ...                                ...
# 118078     149187       Jerusalem Artichoke Stir Fry
# 118079     149188           Asian Apple Pear Compote
# 118080     149189             Skillet Sweet Potatoes
# 118081     149190                Any-Flavour Cookies
# 118082     149191        Fig Newton " Sarah - Bars "
#
#                                         Recipe Ingredient  Total Ingredient  \
# 0       ['black pepper', 'cumin', 'garlic', 'sea salt'...                10
# 1       ['green bean carrot', 'vegetable oil', 'bay le...                 9
# 2       ['okra', 'salt black pepper', 'lamb shoulder',...                 7
# ...

# %%
recipesm_cutoff_10.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Carbon_Footprint_July23/Data/RecipeCF/Cutoff_10_RecipeDB_CF_with_string_matching.csv', index=False)

# %% [markdown]
# # without SM

# %%
recipe = pd.read_csv("D:/IIITD/Mansi_Thesis_Research/Foodprint/Carbon_Footprint_July23/Data/RecipeCF/RecipeDB_CF_without_string_matching.csv")
recipe
# Out:
#         Recipe ID                        Recipe Name  \
# 0            2610               Egyptian Lentil Soup
# 1            2611  Egyptian Green Beans with Carrots
# 2            2612                     Egyptian Bamia
# 3            2613        Magpie's Easy Falafel Cakes
# 4            2614                             Dukkah
# ...           ...                                ...
# 118078     149187       Jerusalem Artichoke Stir Fry
# 118079     149188           Asian Apple Pear Compote
# 118080     149189             Skillet Sweet Potatoes
# 118081     149190                Any-Flavour Cookies
# 118082     149191        Fig Newton " Sarah - Bars "
#
#                                         Recipe Ingredient  Total Ingredient  \
# 0       ['black pepper', 'cumin', 'garlic', 'sea salt'...                10
# 1       ['green bean carrot', 'vegetable oil', 'bay le...                 9
# 2       ['okra', 'salt black pepper', 'lamb shoulder',...                 7
# ...

# %%
# Select recipes having available percentage coverage greater than or equal to 10 
# this is for recipes where available % is found with string matching

recipe_cutoff_10 = recipe[recipe['Available Percentage'] >= 10.000000]
recipe_cutoff_10
# Out:
#         Recipe ID                        Recipe Name  \
# 0            2610               Egyptian Lentil Soup
# 1            2611  Egyptian Green Beans with Carrots
# 2            2612                     Egyptian Bamia
# 3            2613        Magpie's Easy Falafel Cakes
# 4            2614                             Dukkah
# ...           ...                                ...
# 118078     149187       Jerusalem Artichoke Stir Fry
# 118079     149188           Asian Apple Pear Compote
# 118080     149189             Skillet Sweet Potatoes
# 118081     149190                Any-Flavour Cookies
# 118082     149191        Fig Newton " Sarah - Bars "
#
#                                         Recipe Ingredient  Total Ingredient  \
# 0       ['black pepper', 'cumin', 'garlic', 'sea salt'...                10
# 1       ['green bean carrot', 'vegetable oil', 'bay le...                 9
# 2       ['okra', 'salt black pepper', 'lamb shoulder',...                 7
# ...

# %%
recipe_cutoff_10.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Carbon_Footprint_July23/Data/RecipeCF/Cutoff_10_RecipeDB_CF_without_string_matching.csv', index=False)
