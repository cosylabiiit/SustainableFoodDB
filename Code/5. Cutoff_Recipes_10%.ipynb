# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
recipe_sm = pd.read_csv("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/RecipeDB_CF_with_string_matching.csv")
recipe_sm
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# ...

# %%
# Select recipes having available percentage coverage greater than or equal to 10 

recipesm_cutoff_10 = recipe_sm[recipe_sm['Available Percentage'] >= 10.000000]
recipesm_cutoff_10
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# ...

# %%
recipesm_cutoff_10.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/Cutoff_10_RecipeDB_CF_with_string_matching.csv', index=False)

# %% [markdown]
# # without SM

# %%
recipe = pd.read_csv("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/RecipeDB_CF_without_string_matching.csv")
recipe
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# ...

# %%
# Select recipes having available percentage coverage greater than or equal to 10 
# this is for recipes where available % is found with string matching

recipe_cutoff_10 = recipe[recipe['Available Percentage'] >= 10.000000]
recipe_cutoff_10
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# ...

# %%
recipe_cutoff_10.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/Cutoff_10_RecipeDB_CF_without_string_matching.csv', index=False)
