# %%
#import all the required library
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statistics
from scipy.stats import sem

# %% [markdown]
# Find CF with String Matching for all available ingredients and recipes

# %%
#load the required data
input_file = pd.read_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/FinalList_with_sm.csv', encoding='latin1')

# %%
input_file
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# 0                     10  ['cumin', 'garlic', 'carrot', 'coriander', 're...
# 1                      9  ['green bean carrot', 'vegetable oil', 'garlic...
# 2                      7  ['okra', 'lamb shoulder', 'tomato sauce', 'wat...
# 3                     10  ['cornmeal', 'cumin', 'garlic', 'coriander', '...
# 4                      6      ['coriander seed', 'sesame seed', 'hazelnut']
# ...                  ...                                                ...
# 118078                10  ['mushroom', 'garlic', 'celery', 'red pepper',...
# 118079                 4                  ['asian pear', 'water', 'ginger']
# 118080                 6  ['potato', 'pepper', 'vegetable stock', 'onion...
# 118081                 7  ['vanilla', 'flour', 'sugar', 'margarine', 'li...
# 118082                 8  ['fig', 'raisin', 'vanilla', 'water', 'butter'...
#
#         Available Count                          Not Available Ingredients  \
# 0                     8                       ['black pepper', 'sea salt']
# 1                     6      ['bay leaf', 'cardamom', 'salt black pepper']
# 2                     6                              ['salt black pepper']
# 3                     8                                  ['sauce', 'salt']
# 4                     3         ['black pepper', 'sea salt', 'cumin seed']
# ...                 ...                                                ...
# 118078                5  ['yellow pepper', 'jalapeno pepper', 'vegetabl...
# 118079                3                                  ['cardamom seed']
# 118080                5                                           ['salt']
# 118081                5                          ['baking powder', 'salt']
# 118082                7                                       ['sea salt']
#
#         Not Available Count  Available Percentage
# 0                         2             80.000000
# 1                         3             66.666667
# 2                         1             85.714286
# 3                         2             80.000000
# 4                         3             50.000000
# ...                     ...                   ...
# 118078                    5             50.000000
# 118079                    1             75.000000
# 118080                    1             83.333333
# 118081                    2             71.428571
# 118082                    1             87.500000
#
# [118083 rows x 8 columns]

# %%
df_result = pd.read_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Recipedb_mapped_ing_CF.csv')

# %%
df_result
# Out:
#                      RecipeDB Ingredient   Sueatable Ingredient  Similarity  \
# 0                                  onion                  ONION    1.000001
# 1                                 butter                 BUTTER    1.000000
# 2                           garlic clove                 GARLIC    0.930919
# 3                                  water                  WATER    1.000000
# 4                              olive oil              OLIVE OIL    1.000000
# ...                                  ...                    ...         ...
# 7748                 dutch cocoa hershey     HAZELNUT CHOCOLATE    0.823729
# 7749              milk chocolate hershey         MILK CHOCOLATE    0.947778
# 7750  chocolate flavor crisp rice cereal  CHOCOLATE CREAM COOKY    0.818652
# 7751          chocolate ripple ice cream  CHOCOLATE CREAM COOKY    0.925916
# 7752               caramel topping syrup        CRANBERRY JUICE    0.852054
#
#         CF
# 0     0.24
# 1     9.90
# 2     0.67
# 3     0.49
# 4     3.84
# ...    ...
# 7748  3.43
# 7749  3.60
# 7750  1.69
# 7751  1.69
# 7752  2.88
#
# [7753 rows x 4 columns]

# %% [markdown]
# # Calculate cf for each recipe after string matching

# %%
# create a dictionary to map ingredients to their carbon footprints
ingredient_dict = dict(zip(df_result['RecipeDB Ingredient'].str.lower(), df_result['CF']))
# print(ingredient_dict)

# create a function to compute the sum of carbon footprints for a list of ingredients
def compute_sum(ingredients):
    ingredients = [x.strip(" '[]") for x in ingredients.split(",")]
    
    # map the ingredients to their carbon footprints using the dictionary
    carbon_footprints = []
    for ing in ingredients:
        if ing.lower() in ingredient_dict:
            carbon_footprints.append(ingredient_dict[ing.lower()])
        else:
            carbon_footprints.append(0)

    return sum(carbon_footprints)

df_sum = pd.DataFrame({'Ingredients': input_file['Available Ingredients'], 
                       'carbon_footprint_sum': input_file['Available Ingredients'].apply(compute_sum)})
df_sum
# Out:
#                                               Ingredients  \
# 0       ['cumin', 'garlic', 'carrot', 'coriander', 're...
# 1       ['green bean carrot', 'vegetable oil', 'garlic...
# 2       ['okra', 'lamb shoulder', 'tomato sauce', 'wat...
# 3       ['cornmeal', 'cumin', 'garlic', 'coriander', '...
# 4           ['coriander seed', 'sesame seed', 'hazelnut']
# ...                                                   ...
# 118078  ['mushroom', 'garlic', 'celery', 'red pepper',...
# 118079                  ['asian pear', 'water', 'ginger']
# 118080  ['potato', 'pepper', 'vegetable stock', 'onion...
# 118081  ['vanilla', 'flour', 'sugar', 'margarine', 'li...
# 118082  ['fig', 'raisin', 'vanilla', 'water', 'butter'...
#
#         carbon_footprint_sum
# 0                       5.56
# 1                       6.86
# 2                      32.06
# 3                      15.59
# 4                       2.27
# ...                      ...
# 118078                  4.15
# 118079                  1.66
# 118080                  5.60
# 118081                  8.48
# 118082                 20.56
#
# [118083 rows x 2 columns]

# %%
input_file['Recipe_CF'] = input_file['Available Ingredients'].apply(compute_sum)
input_file
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# 0                     10  ['cumin', 'garlic', 'carrot', 'coriander', 're...
# 1                      9  ['green bean carrot', 'vegetable oil', 'garlic...
# 2                      7  ['okra', 'lamb shoulder', 'tomato sauce', 'wat...
# 3                     10  ['cornmeal', 'cumin', 'garlic', 'coriander', '...
# 4                      6      ['coriander seed', 'sesame seed', 'hazelnut']
# ...                  ...                                                ...
# 118078                10  ['mushroom', 'garlic', 'celery', 'red pepper',...
# 118079                 4                  ['asian pear', 'water', 'ginger']
# 118080                 6  ['potato', 'pepper', 'vegetable stock', 'onion...
# 118081                 7  ['vanilla', 'flour', 'sugar', 'margarine', 'li...
# 118082                 8  ['fig', 'raisin', 'vanilla', 'water', 'butter'...
#
#         Available Count                          Not Available Ingredients  \
# 0                     8                       ['black pepper', 'sea salt']
# 1                     6      ['bay leaf', 'cardamom', 'salt black pepper']
# 2                     6                              ['salt black pepper']
# 3                     8                                  ['sauce', 'salt']
# 4                     3         ['black pepper', 'sea salt', 'cumin seed']
# ...                 ...                                                ...
# 118078                5  ['yellow pepper', 'jalapeno pepper', 'vegetabl...
# 118079                3                                  ['cardamom seed']
# 118080                5                                           ['salt']
# 118081                5                          ['baking powder', 'salt']
# 118082                7                                       ['sea salt']
#
#         Not Available Count  Available Percentage  Recipe_CF
# 0                         2             80.000000       5.56
# 1                         3             66.666667       6.86
# 2                         1             85.714286      32.06
# 3                         2             80.000000      15.59
# 4                         3             50.000000       2.27
# ...                     ...                   ...        ...
# 118078                    5             50.000000       4.15
# 118079                    1             75.000000       1.66
# 118080                    1             83.333333       5.60
# 118081                    2             71.428571       8.48
# 118082                    1             87.500000      20.56
#
# [118083 rows x 9 columns]

# %%
input_file.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/RecipeDB_CF_with_string_matching.csv', index=False)
