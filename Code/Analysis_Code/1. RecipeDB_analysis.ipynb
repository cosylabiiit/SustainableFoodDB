# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
input_file = pd.read_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Recipe_cfp.csv')

# %%
input_file
# Out:
#             ID                                        ingredients  \
# 0       709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1       905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2       725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3       114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4       440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...        ...                                                ...
# 118078  523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079  660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080  742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081  779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082  674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#                 region
# 0       Middle Eastern
# 1       Middle Eastern
# 2       Middle Eastern
# 3       Middle Eastern
# 4       Middle Eastern
# ...                ...
# 118078        Canadian
# 118079        Canadian
# 118080        Canadian
# 118081        Canadian
# 118082        Canadian
#
# [118083 rows x 3 columns]

# %%
#read the csv file
cf_sm = pd.read_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/RecipeCF/RecipeDB_CF_with_string_matching.csv', encoding='latin1')

# %%
cf_sm
# Out:
#         Recipe ID                                  Recipe Ingredient  \
# 0          709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1          905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2          725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3          114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4          440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...           ...                                                ...
# 118078     523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079     660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080     742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081     779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082     674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
#         Total Ingredient                              Available Ingredients  \
# 0                     10  ['cumin', 'garlic', 'carrot', 'coriander', 're...
# 1                      9  ['green bean carrot', 'vegetable oil', 'garlic...
# 2                      7  ['okra', 'lamb shoulder', 'tomato sauce', 'wat...
# 3                     10  ['cornmeal', 'cumin', 'garlic', 'coriander', '...
# 4                      6      ['coriander seed', 'sesame seed', 'hazelnut']
# ...                  ...                                                ...
# 118078                10  ['mushroom', 'garlic', 'celery', 'red pepper',...
# 118079                 4                  ['asian pear', 'water', 'ginger']
# 118080                 6  ['potato', 'pepper', 'vegetable stock', 'onion...
# 118081                 7  ['vanilla', 'flour', 'sugar', 'margarine', 'li...
# 118082                 8  ['fig', 'raisin', 'vanilla', 'water', 'butter'...
#
#         Available Count                          Not Available Ingredients  \
# 0                     8                       ['black pepper', 'sea salt']
# 1                     6      ['bay leaf', 'cardamom', 'salt black pepper']
# 2                     6                              ['salt black pepper']
# 3                     8                                  ['sauce', 'salt']
# 4                     3         ['black pepper', 'sea salt', 'cumin seed']
# ...                 ...                                                ...
# 118078                5  ['yellow pepper', 'jalapeno pepper', 'vegetabl...
# 118079                3                                  ['cardamom seed']
# 118080                5                                           ['salt']
# 118081                5                          ['baking powder', 'salt']
# 118082                7                                       ['sea salt']
#
#         Not Available Count  Available Percentage  Recipe_CF
# 0                         2             80.000000       5.56
# 1                         3             66.666667       6.86
# 2                         1             85.714286      32.06
# 3                         2             80.000000      15.59
# 4                         3             50.000000       2.27
# ...                     ...                   ...        ...
# 118078                    5             50.000000       4.15
# 118079                    1             75.000000       1.66
# 118080                    1             83.333333       5.60
# 118081                    2             71.428571       8.48
# 118082                    1             87.500000      20.56
#
# [118083 rows x 9 columns]

# %%
recipe = input_file[['ID', 'ingredients']]
recipe
# Out:
#             ID                                        ingredients
# 0       709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...
# 1       905901  ['green bean carrot', 'vegetable oil', 'bay le...
# 2       725971  ['okra', 'salt black pepper', 'lamb shoulder',...
# 3       114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...
# 4       440574  ['black pepper', 'sea salt', 'cumin seed', 'co...
# ...        ...                                                ...
# 118078  523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...
# 118079  660518  ['cardamom seed', 'asian pear', 'water', 'ging...
# 118080  742230  ['potato', 'pepper', 'vegetable stock', 'salt'...
# 118081  779223  ['baking powder', 'vanilla', 'flour', 'sugar',...
# 118082  674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...
#
# [118083 rows x 2 columns]

# %% [markdown]
# # Recipe size distribution

# %%
x =[]
for i in range(input_file["ID"].nunique()):
    s = len(input_file['ingredients'][i].split(','))
    x.append(s)

# %%
recipe['item_count']= x
recipe
# Out:
#             ID                                        ingredients  item_count
# 0       709824  ['black pepper', 'cumin', 'garlic', 'sea salt'...          10
# 1       905901  ['green bean carrot', 'vegetable oil', 'bay le...           9
# 2       725971  ['okra', 'salt black pepper', 'lamb shoulder',...           7
# 3       114702  ['cornmeal', 'cumin', 'sauce', 'garlic', 'cori...          10
# 4       440574  ['black pepper', 'sea salt', 'cumin seed', 'co...           6
# ...        ...                                                ...         ...
# 118078  523830  ['yellow pepper', 'mushroom', 'garlic', 'jalap...          10
# 118079  660518  ['cardamom seed', 'asian pear', 'water', 'ging...           4
# 118080  742230  ['potato', 'pepper', 'vegetable stock', 'salt'...           6
# 118081  779223  ['baking powder', 'vanilla', 'flour', 'sugar',...           7
# 118082  674570  ['fig', 'sea salt', 'raisin', 'vanilla', 'wate...           8
#
# [118083 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

recipe_sizes = []
for i in range(recipe["ID"].nunique()):
    s = len(recipe['ingredients'][i].split(','))
    recipe_sizes.append(s)

unique_sizes, counts = np.unique(recipe_sizes, return_counts=True)

total_recipes = len(recipe_sizes)
percentages = (counts / total_recipes) * 100

plt.figure(figsize=(8, 6))

plt.plot(unique_sizes, percentages, marker='o', color='black',markerfacecolor='blue')

plt.xlabel("Ingredients per recipe ($s$)", fontsize=12)
plt.ylabel("P($s$)", fontsize=12)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

recipe_sizes = []
for i in range(recipe["ID"].nunique()):
    s = len(recipe['ingredients'][i].split(','))
    recipe_sizes.append(s)

unique_sizes, counts = np.unique(recipe_sizes, return_counts=True)

ava_sizes = []
for i in range(cf_sm["Recipe ID"].nunique()):
    s = len(cf_sm['Available Ingredients'][i].split(','))
    ava_sizes.append(s)

ava_unique_sizes, ava_counts = np.unique(ava_sizes, return_counts=True)

total_recipes = recipe["ID"].nunique()
percentages = (counts / total_recipes) * 100
ava_percentages = (ava_counts / total_recipes) * 100

plt.figure(figsize=(10, 6))

plt.plot(unique_sizes, percentages, marker='o', color='blue', label='RecipeDB')
plt.plot(ava_unique_sizes, ava_percentages, marker='o', color='orange', label='Mapped to SuEatable')

plt.xlabel("Ingredients per recipe (recipe size)", fontsize=12, fontname="Arial")
plt.ylabel("Percentage of recipes", fontsize=12, fontname="Arial")
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.margins(x=0.01, tight=True)
plt.legend()

plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Recipesize_dist_total_ava.jpeg", dpi=300)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

recipe_sizes = []
for i in range(recipe["ID"].nunique()):
    s = len(recipe['ingredients'][i].split(','))
    recipe_sizes.append(s)

unique_sizes, counts = np.unique(recipe_sizes, return_counts=True)

ava_sizes = []
for i in range(cf_sm["Recipe ID"].nunique()):
    s = len(cf_sm['Available Ingredients'][i].split(','))
    ava_sizes.append(s)

ava_unique_sizes, ava_counts = np.unique(ava_sizes, return_counts=True)

total_recipes = recipe["ID"].nunique()
percentages = (counts / total_recipes) * 100
ava_percentages = (ava_counts / total_recipes) * 100

plt.figure(figsize=(10, 6))

#average recipe size
mean_recipe_size = np.mean(recipe_sizes)
mean_ava_recipe_size = np.mean(ava_sizes)

# Plot dotted mean lines in the background
plt.axvline(x=mean_recipe_size, color='blue', linestyle='--')
plt.axvline(x=mean_ava_recipe_size, color='orange', linestyle='--')

plt.plot(unique_sizes, percentages, marker='o', color='blue', label='RecipeDB')
plt.plot(ava_unique_sizes, ava_percentages, marker='o', color='orange', label='Mapped to SuEatable')


plt.xlabel("Ingredients per recipe (recipe size)", fontsize=12, fontname="Arial")
plt.ylabel("Percentage of recipes", fontsize=12, fontname="Arial")
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.margins(x=0.01, tight=True)
plt.legend()

plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Recipesize_dist_total_ava_with_avg_dotted_lines.svg", dpi=300)

plt.show()

# %% [markdown]
# # Frequency Rank Distrubution

# %%
import ast
import operator
count = {}

recipes = recipe["ID"].nunique()

for i in range(recipes):
    r = recipe['ingredients'][i]
    res = ast.literal_eval(r)
    for k in res:
        count[k] = count.get(k,0) + 1
sorted_d = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True))

y=[]
for i in sorted_d.values():
    y.append(i)
    
x=[]
for i in range(20279):
    x.append(i)
    
plt.loglog(x,y,base=10)
plt.gcf().set_size_inches(8,6)
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.show()

# %%
import ast
import operator
count = {}

recipes = recipe["ID"].nunique()

for i in range(recipes):
    ava = cf_sm['Available Ingredients'][i]
    res = ast.literal_eval(ava)
    for k in res:
        count[k] = count.get(k,0) + 1
ava_sorted_d = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True))

y=[]
for i in ava_sorted_d.values():
    y.append(i)
    
x=[]
for i in range(7752):
    x.append(i)
    
plt.loglog(x,y,base=10)
plt.gcf().set_size_inches(8,6)
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.show()

# %%
import ast
import operator
count = {}
ava_count= {}

recipes = recipe["ID"].nunique()

for i in range(recipes):
    r = recipe['ingredients'][i]
    res = ast.literal_eval(r)
    for k in res:
        count[k] = count.get(k,0) + 1
sorted_d = dict(sorted(count.items(), key=operator.itemgetter(1),reverse=True))

y=[]
for i in sorted_d.values():
    y.append(i)
    
x=[]
for i in range(20279):
    x.append(i)

for i in range(recipes):
    ava = cf_sm['Available Ingredients'][i]
    res = ast.literal_eval(ava)
    for k in res:
        ava_count[k] = ava_count.get(k,0) + 1
ava_sorted_d = dict(sorted(ava_count.items(), key=operator.itemgetter(1),reverse=True))

y1=[]
for i in ava_sorted_d.values():
    y1.append(i)
    
x1=[]
for i in range(7752):
    x1.append(i)
  
plt.loglog(x,y,base=10, color='blue', label='RecipeDB')
plt.loglog(x1,y1,base=10, color='orange', label='Mapped to SuEatable')

plt.gcf().set_size_inches(8,6)
plt.xlabel("Popularity rank of food product", fontsize=12, fontname="Arial")
plt.ylabel("Number of recipes",  fontsize=12, fontname="Arial")

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend()

plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Freq_rank_total_ava.jpeg", dpi=300)
# plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Freq_rank_total_ava.svg", dpi=300)

plt.show()

# %%
import ast
import operator
import matplotlib.pyplot as plt

count = {}
ava_count = {}

recipes = recipe["ID"].nunique()

for i in range(recipes):
    r = recipe['ingredients'][i]
    res = ast.literal_eval(r)
    for k in res:
        count[k] = count.get(k, 0) + 1

# Sort ingredients by frequency and select the top 100
sorted_d = dict(sorted(count.items(), key=operator.itemgetter(1), reverse=True)[:100])

y = list(sorted_d.values())
x = list(range(1, 101))  # Create a list of ranks from 1 to 100

for i in range(recipes):
    ava = cf_sm['Available Ingredients'][i]
    res = ast.literal_eval(ava)
    for k in res:
        ava_count[k] = ava_count.get(k, 0) + 1

# Sort available ingredients by frequency and select the top 100
ava_sorted_d = dict(sorted(ava_count.items(), key=operator.itemgetter(1), reverse=True)[:100])

y1 = list(ava_sorted_d.values())
x1 = list(range(1, 101))  # Create a list of ranks from 1 to 100

plt.loglog(x, y, base=10, color='blue', label='RecipeDB')
plt.loglog(x1, y1, base=10, color='orange', label='Mapped to SuEatable')

plt.gcf().set_size_inches(8, 6)
# plt.xlabel("Popularity rank of food product", fontsize=12, fontname="Arial")
# plt.ylabel("Number of recipes", fontsize=12, fontname="Arial")

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.legend()
plt.xlim(0.98,101)


plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Freq_rank_top_100_ava.jpeg", dpi=300)
plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Freq_rank_top_100_ava.svg", dpi=300)

plt.show()

# %%
len(sorted_d)
# Out:
# 100

# %% [markdown]
# **Top 20 available ingredients**

# %%
top_ingredients = list(ava_sorted_d.keys())[:20]
ingredient_counts = list(ava_sorted_d.values())[:20]

# total_count = 10189
# ingredient_percentages = [(count / total_count) * 100 for count in ingredient_counts]

plt.figure(figsize=(10, 8))
plt.bar(top_ingredients, ingredient_counts, color='lightblue')
# plt.bar(top_ingredients, ingredient_percentages, color='lightblue')
plt.xlabel("Ingredients")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# **Top 20 RecipeDB ingredients**

# %%
top_ingredients = list(sorted_d.keys())[:20]
ingredient_counts = list(sorted_d.values())[:20]

# total_count = 10189
# ingredient_percentages = [(count / total_count) * 100 for count in ingredient_counts]


plt.figure(figsize=(10, 8))
plt.bar(top_ingredients, ingredient_counts, color='lightblue')
# plt.bar(top_ingredients, ingredient_percentages, color='lightblue')
plt.xlabel("Ingredients")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# # Ingredients and its CF values

# %%
mapped_cf = pd.read_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Recipedb_mapped_ing_CF.csv')

# %%
mapped_cf
# Out:
#                      RecipeDB Ingredient   Sueatable Ingredient  Similarity  \
# 0                                  onion                  ONION    1.000001
# 1                                 butter                 BUTTER    1.000000
# 2                           garlic clove                 GARLIC    0.930919
# 3                                  water                  WATER    1.000000
# 4                              olive oil              OLIVE OIL    1.000000
# ...                                  ...                    ...         ...
# 7748                 dutch cocoa hershey     HAZELNUT CHOCOLATE    0.823729
# 7749              milk chocolate hershey         MILK CHOCOLATE    0.947778
# 7750  chocolate flavor crisp rice cereal  CHOCOLATE CREAM COOKY    0.818652
# 7751          chocolate ripple ice cream  CHOCOLATE CREAM COOKY    0.925916
# 7752               caramel topping syrup        CRANBERRY JUICE    0.852054
#
#         CF
# 0     0.24
# 1     9.90
# 2     0.67
# 3     0.49
# 4     3.84
# ...    ...
# 7748  3.43
# 7749  3.60
# 7750  1.69
# 7751  1.69
# 7752  2.88
#
# [7753 rows x 4 columns]

# %%
for i in range(recipes):
    ava = cf_sm['Available Ingredients'][i]
    res = ast.literal_eval(ava)
    for k in res:
        ava_count[k] = ava_count.get(k,0) + 1
ava_sorted_d = dict(sorted(ava_count.items(), key=operator.itemgetter(1),reverse=True))
ava_sorted_d
# Out:
# {'onion': 69096,
#  'butter': 54026,
#  'garlic clove': 49786,
#  'water': 49546,
#  'olive oil': 44782,
#  'egg': 43722,
#  'sugar': 40542,
#  'tomato': 33250,
#  'garlic': 30872,
#  'milk': 29170,
#  'pepper': 24608,
#  'salt pepper': 20774,
#  'flour': 19674,
#  'cinnamon': 19248,
#  'lemon juice': 19018,
#  'carrot': 18174,
#  'purpose flour': 18046,
#  'vegetable oil': 18036,
#  'cumin': 17984,
#  'cream': 17160,
#  'ginger': 16816,
#  'parmesan cheese': 15578,
#  'soy sauce': 15454,
#  'beef': 15348,
#  'potato': 14528,
#  'green onion': 14148,
#  'chicken broth': 11826,
#  'lemon': 10986,
#  'lime juice': 10956,
#  'chicken breast': 10792,
#  'mushroom': 10284,
#  'garlic powder': 9532,
#  'celery': 9216,
#  'cheddar cheese': 8996,
#  'cornstarch': 8776,
#  'nutmeg': 8486,
#  'white wine': 7944,
#  'vanilla extract': 7912,
#  'honey': 7906,
#  'red bell pepper': 7820,
#  'tomato paste': 7636,
#  'coriander': 7412,
#  'chicken': 7178,
#  'tomato sauce': 6962,
#  'mozzarella cheese': 6936,
#  'almond': 6616,
#  'bacon': 6516,
#  'green bell pepper': 6344,
#  'red pepper': 6330,
#  'turmeric': 6216,
#  'cream cheese': 6188,
#  'rice': 6122,
#  'mayonnaise': 5986,
#  'egg yolk': 5810,
#  'shallot': 5648,
#  'green pepper': 5622,
#  'vanilla': 5548,
#  'sesame oil': 5522,
#  'chicken stock': 5336,
#  'scallion': 5248,
#  'zucchini': 5150,
#  'spinach': 5048,
#  'shrimp': 4888,
#  'green chilies': 4880,
#  'breadcrumb': 4758,
#  'raisin': 4688,
#  'orange juice': 4654,
#  'red wine': 4632,
#  'cucumber': 4614,
#  'beef broth': 4604,
#  'lime': 4562,
#  'coconut milk': 4498,
#  'yellow onion': 4480,
#  'egg white': 4476,
#  'avocado': 4402,
#  'feta cheese': 4192,
#  'flour tortilla': 4058,
#  'red wine vinegar': 4016,
#  'coconut': 3810,
#  'walnut': 3802,
#  'lemon zest': 3702,
#  'cheese': 3694,
#  'sesame seed': 3682,
#  'corn': 3616,
#  'pork': 3610,
#  'fish sauce': 3602,
#  'pea': 3424,
#  'chicken breast half': 3362,
#  'margarine': 3342,
#  'monterey jack cheese': 3182,
#  'gingerroot': 3122,
#  'chive': 3062,
#  'onion powder': 3032,
#  'plain yogurt': 3018,
#  'ketchup': 2962,
#  'dill': 2954,
#  'orange': 2944,
#  'apple': 2918,
#  'corn tortilla': 2808,
#  'green bean': 2794,
#  'ricotta cheese': 2788,
#  'cabbage': 2770,
#  'eggplant': 2724,
#  'peanut oil': 2680,
#  'yeast': 2672,
#  'bell pepper': 2530,
#  'peanut': 2526,
#  'rice vinegar': 2490,
#  'whipping cream': 2466,
#  'leek': 2454,
#  'banana': 2440,
#  'chicken thigh': 2348,
#  'caster sugar': 2336,
#  'plain flour': 2334,
#  'bread': 2302,
#  'grain rice': 2254,
#  'buttermilk': 2246,
#  'garlic salt': 2220,
#  'lettuce': 2200,
#  'strawberry': 2154,
#  'plum tomato': 2138,
#  'chocolate': 2098,
#  'chickpea': 2096,
#  'rom tomato': 2092,
#  'cherry tomato': 2064,
#  "confectioner ' sugar": 2004,
#  'cooking spray': 1968,
#  'vegetable broth': 1950,
#  'mango': 1944,
#  'pineapple': 1942,
#  'cocoa powder': 1934,
#  'yogurt': 1902,
#  'lamb': 1880,
#  'bean': 1876,
#  'tomato juice': 1866,
#  'spaghetti': 1848,
#  'beef stock': 1840,
#  'orange zest': 1802,
#  'coriander leaf': 1778,
#  'kalamata olive': 1776,
#  'wheat flour': 1766,
#  'beer': 1748,
#  'tomato puree': 1720,
#  'white wine vinegar': 1680,
#  'peanut butter': 1658,
#  'icing sugar': 1654,
#  'olive': 1648,
#  'pasta': 1602,
#  'basmati rice': 1592,
#  'marjoram': 1590,
#  'bean sprout': 1570,
#  'fennel seed': 1542,
#  'broccoli': 1536,
#  'coriander seed': 1530,
#  'red chilies': 1528,
#  'vegetable stock': 1518,
#  'tofu': 1496,
#  'lemongrass': 1496,
#  'chocolate chip': 1470,
#  'almond extract': 1432,
#  'green olive': 1414,
#  'cottage cheese': 1410,
#  'artichoke heart': 1374,
#  'apricot': 1360,
#  'coffee': 1356,
#  'garbanzo bean': 1352,
#  'self raising flour': 1344,
#  'cornmeal': 1320,
#  'cornflour': 1310,
#  'pineapple juice': 1306,
#  'button mushroom': 1284,
#  'oat': 1244,
#  'corn kernel': 1244,
#  'kernel corn': 1240,
#  'cashew': 1210,
#  'asparagus': 1206,
#  'date': 1202,
#  'dark brown sugar': 1178,
#  'cauliflower': 1176,
#  'green pea': 1154,
#  'pepper sauce': 1154,
#  'peppercorn': 1138,
#  'sausage': 1138,
#  'bread flour': 1134,
#  'prosciutto': 1114,
#  'sun tomato': 1098,
#  'shiitake mushroom': 1088,
#  'broccoli floret': 1078,
#  'cranberry': 1074,
#  'provolone cheese': 1068,
#  'apple cider vinegar': 1060,
#  'chorizo sausage': 1060,
#  'confectioner sugar': 1046,
#  'bread crumb': 1046,
#  'cocoa': 1028,
#  'lime wedge': 1024,
#  'greek yogurt': 1022,
#  'lentil': 1014,
#  'corn syrup': 1014,
#  'raspberry': 998,
#  'mirin': 996,
#  'currant': 988,
#  'blueberry': 982,
#  'romaine lettuce': 978,
#  'thyme leaf': 974,
#  'lime zest': 972,
#  'salmon fillet': 960,
#  'russet potato': 952,
#  'beef bouillon cube': 950,
#  'tortilla': 948,
#  'baby spinach': 946,
#  'penne pasta': 932,
#  'vegetable': 924,
#  'egg noodle': 920,
#  'romano cheese': 902,
#  'salmon': 900,
#  'goat cheese': 892,
#  'pork chop': 892,
#  'tomatillo': 892,
#  'cannellini bean': 880,
#  'beef stew meat': 876,
#  'arborio rice': 838,
#  'stewing beef': 836,
#  'pork tenderloin': 832,
#  'peach': 828,
#  'pita bread': 826,
#  'sake': 826,
#  'pumpkin': 826,
#  'hazelnut': 820,
#  'gruyere cheese': 810,
#  'chicken bouillon cube': 808,
#  'pistachio': 804,
#  'green chili': 798,
#  'tomato soup': 796,
#  'lemon wedge': 794,
#  'nut': 794,
#  'rice wine': 792,
#  'cherry': 784,
#  'ginger root': 780,
#  'red capsicum': 780,
#  'granny smith apple': 778,
#  'celery seed': 778,
#  'beef steak': 776,
#  'linguine': 774,
#  'cream tartar': 770,
#  'dark chocolate': 748,
#  'butternut squash': 736,
#  'english cucumber': 736,
#  'lettuce leaf': 726,
#  'pear': 718,
#  'radish': 714,
#  'pepperoni': 704,
#  'self rising flour': 702,
#  'vanilla essence': 698,
#  'parsnip': 696,
#  'lemon peel': 680,
#  'cake flour': 678,
#  'green cabbage': 676,
#  'sirloin steak': 676,
#  'vanilla ice cream': 676,
#  'fruit': 674,
#  'turnip': 672,
#  'beef brisket': 670,
#  'grape tomato': 664,
#  'sunflower oil': 664,
#  'orzo pasta': 662,
#  'mussel': 662,
#  'pie crust': 662,
#  'pancetta': 662,
#  'tomato green chilies': 660,
#  'spinach leaf': 648,
#  'apple juice': 644,
#  'prawn': 642,
#  'anchovy fillet': 642,
#  'corn oil': 638,
#  'blue cheese': 636,
#  'celery salt': 624,
#  'garlic paste': 618,
#  'superfine sugar': 616,
#  'pineapple chunk': 616,
#  'poppy seed': 610,
#  'rice noodle': 608,
#  'red lentil': 600,
#  'rice flour': 600,
#  'white flour': 598,
#  'ginger paste': 584,
#  'pork shoulder': 582,
#  'vanilla bean': 580,
#  'pork loin': 570,
#  'chicken bouillon': 568,
#  'spanish onion': 564,
#  'serrano pepper': 558,
#  'onion flake': 556,
#  'chicken wing': 548,
#  'beef tenderloin': 546,
#  'soya sauce': 540,
#  'tuna': 538,
#  'clam': 536,
#  'mascarpone cheese': 536,
#  'orange peel': 528,
#  'applesauce': 526,
#  'red cabbage': 522,
#  'coconut cream': 506,
#  'fennel bulb': 504,
#  'beef roast': 504,
#  'fig': 504,
#  'okra': 496,
#  'leg lamb': 494,
#  'lemon pepper': 494,
#  'red curry paste': 492,
#  'lard': 486,
#  'palm sugar': 486,
#  'cremini mushroom': 484,
#  'double cream': 474,
#  'pimiento': 470,
#  'portabella mushroom': 468,
#  'poblano pepper': 468,
#  'kale': 466,
#  'quinoa': 464,
#  'head cabbage': 458,
#  'dill pickle': 454,
#  'sun tomato oil': 452,
#  'wonton wrapper': 448,
#  'veal': 446,
#  'creamy peanut butter': 444,
#  'fettuccine': 444,
#  'pasta sauce': 444,
#  'pecorino romano cheese': 440,
#  'sirloin': 438,
#  'chicken bouillon granule': 436,
#  'beef bouillon': 434,
#  'arugula': 434,
#  'roast beef': 434,
#  'pork sausage': 430,
#  'panko breadcrumb': 430,
#  'beef chuck': 428,
#  'green chile': 426,
#  'topping': 424,
#  'roasting chicken': 422,
#  'sunflower seed': 422,
#  'fine breadcrumb': 422,
#  'beef chuck roast': 420,
#  'watercress': 418,
#  'tamarind paste': 416,
#  'oatmeal': 414,
#  'scallop': 410,
#  'vegetable shortening': 410,
#  'coconut oil': 410,
#  'part mozzarella cheese': 404,
#  'velveeta cheese': 404,
#  'nori': 402,
#  'macaroni': 402,
#  'rigatoni pasta': 400,
#  'wine': 398,
#  'fennel': 398,
#  'penne': 394,
#  'tart apple': 388,
#  'asiago cheese': 386,
#  'lemon juice zest': 384,
#  'harissa': 378,
#  'wheat bread': 378,
#  'chicken leg': 378,
#  'cauliflower floret': 376,
#  'apple cider': 376,
#  'cashew nut': 370,
#  'vermouth': 370,
#  'apricot jam': 364,
#  'anchovy': 356,
#  'asparagus spear': 356,
#  'barley': 354,
#  'plantain': 348,
#  'colby monterey jack cheese': 348,
#  'vidalia onion': 348,
#  'splenda sugar substitute': 348,
#  'macadamia nut': 344,
#  'orange marmalade': 344,
#  'olive oil cooking spray': 344,
#  'red chili': 344,
#  'watermelon': 342,
#  'beef sirloin steak': 338,
#  'rotini pasta': 338,
#  'noodle': 334,
#  'beef rib': 334,
#  'raspberry jam': 334,
#  'pepperoncini pepper': 332,
#  'egg substitute': 328,
#  'lamb shoulder': 326,
#  'kiwi fruit': 326,
#  'rhubarb': 326,
#  'soymilk': 324,
#  'onion salt': 318,
#  'fish fillet': 316,
#  'crouton': 316,
#  'beef sirloin': 314,
#  'porcini mushroom': 314,
#  'mango chutney': 308,
#  'vanilla sugar': 306,
#  'chicken drumstick': 302,
#  'extra tofu': 302,
#  'orange liqueur': 302,
#  'wheat tortilla': 302,
#  'wide egg noodle': 302,
#  'ginger powder': 302,
#  'green cardamom pod': 300,
#  'pistachio nut': 298,
#  'green cardamom': 298,
#  'corn flake': 298,
#  'fontina cheese': 296,
#  'rye flour': 296,
#  'cooking oat': 294,
#  'tomato ketchup': 292,
#  'pumpkin puree': 290,
#  'green curry paste': 290,
#  'sea scallop': 288,
#  'orange juice concentrate': 288,
#  'beef bouillon granule': 286,
#  'blackberry': 286,
#  'apricot preserve': 284,
#  'ziti pasta': 284,
#  'shell pasta': 280,
#  'graham cracker crumb': 278,
#  'beef consomme': 276,
#  'miso': 276,
#  'celery leaf': 276,
#  'part ricotta cheese': 276,
#  'sugar snap pea': 274,
#  'cotija cheese': 274,
#  'chocolate syrup': 274,
#  'green food coloring': 268,
#  'wheat germ': 268,
#  'plum': 268,
#  'vermicelli': 266,
#  'daikon radish': 266,
#  'rotel': 266,
#  'cream corn': 264,
#  'baby corn': 264,
#  'turkey breast': 264,
#  'cooking apple': 264,
#  'squid': 260,
#  'chicken liver': 260,
#  'cranberry juice': 260,
#  'artichoke': 260,
#  'salt pork': 258,
#  'chicken stock cube': 258,
#  'green lentil': 256,
#  'pumpkin seed': 256,
#  'farfalle pasta': 252,
#  'fish': 250,
#  'chicken breast fillet': 250,
#  'rotel tomato': 250,
#  'potato starch': 248,
#  'white rum': 246,
#  'cod fish fillet': 246,
#  'fish stock': 244,
#  'green capsicum': 244,
#  'lamb shank': 242,
#  'pork loin chop': 242,
#  'corn chip': 242,
#  'cod': 240,
#  'brie cheese': 238,
#  'gruyere': 238,
#  'chicken stock vegetable': 238,
#  'chicken meat': 236,
#  'mandarin orange': 236,
#  'chickpea flour': 234,
#  'pork rib': 232,
#  'gouda cheese': 230,
#  'bacon dripping': 230,
#  'cheese tortellini': 228,
#  'sumac': 226,
#  'vanilla pudding mix': 226,
#  'jumbo shrimp': 224,
#  'milk ricotta cheese': 224,
#  'head cauliflower': 222,
#  'corn tortilla chip': 222,
#  'almond paste': 216,
#  'deli ham': 212,
#  'beef gravy': 212,
#  'fava bean': 210,
#  'shrimp paste': 210,
#  'lamb chop': 208,
#  'manchego cheese': 208,
#  'pepper flake': 208,
#  'coffee granule': 206,
#  'curd cottage cheese': 206,
#  'pasta shell': 206,
#  'filet beef': 206,
#  'semolina flour': 204,
#  'head garlic': 204,
#  'chick pea': 204,
#  'panir': 204,
#  'grape': 202,
#  'lemon extract': 200,
#  'mix': 200,
#  'espresso': 200,
#  'pork loin roast': 198,
#  'liquid honey': 198,
#  'aubergine': 198,
#  'beef tenderloin steak': 196,
#  'courgette': 196,
#  'pork butt': 194,
#  'vanilla yogurt': 194,
#  'vegetable juice': 194,
#  'anchovy paste': 192,
#  'pimento olive': 190,
#  'deli roast beef': 190,
#  'red bean': 188,
#  'milk chocolate': 188,
#  'hoagie': 188,
#  'pork roast': 186,
#  'limeade concentrate': 186,
#  'plain nonfat yogurt': 186,
#  'green tomato': 184,
#  'green apple': 182,
#  'biscuit': 182,
#  'cinnamon sugar': 180,
#  'red grape': 180,
#  'romaine lettuce leaf': 180,
#  'egg wrap': 180,
#  'ha avocadoes': 180,
#  'coffee liqueur': 178,
#  'white chocolate chip': 178,
#  'streaky bacon': 178,
#  'lite olive oil': 178,
#  'chunky peanut butter': 176,
#  'bacon bit': 174,
#  'demerara sugar': 174,
#  'glace cherry': 174,
#  'graham cracker': 172,
#  'walnut half': 172,
#  'pork sparerib': 172,
#  'butter bean': 172,
#  'espresso powder': 170,
#  'escarole': 170,
#  'banana pepper': 168,
#  'grape leaf': 168,
#  'pecorino cheese': 168,
#  'tamarind juice': 166,
#  'pimento': 166,
#  'baking chocolate': 166,
#  'andouille sausage': 166,
#  'beef mince': 166,
#  'manicotti': 166,
#  'pickling spice': 164,
#  'ice cream': 164,
#  'syrup': 162,
#  'strawberry jam': 162,
#  'tuna water': 162,
#  'wheat pita bread': 162,
#  'saltine cracker': 162,
#  'ciabatta': 162,
#  'almond milk': 160,
#  'broiler fryer chicken': 160,
#  'orange blossom water': 160,
#  'beetroot': 160,
#  'lebanese cucumber': 160,
#  'mascarpone': 160,
#  'pomegranate seed': 158,
#  'kiwi': 158,
#  'burrito flour tortilla': 158,
#  'grapefruit juice': 158,
#  'kirsch': 158,
#  'gherkin': 158,
#  'chicken tender': 156,
#  'lemonade': 156,
#  'walnut oil': 156,
#  'peanut oil vegetable': 156,
#  'coconut extract': 154,
#  'orange juice zest': 154,
#  'chicken breast meat': 152,
#  'mango powder': 152,
#  'coconut flake': 152,
#  'bacon grease': 150,
#  'tamari soy sauce': 150,
#  'rotel tomato chilies': 150,
#  'pearl onion': 148,
#  'fenugreek': 148,
#  'edamame': 148,
#  'rice paper': 148,
#  'string bean': 148,
#  'pomegranate juice': 146,
#  'green grape': 146,
#  'navel orange': 146,
#  'french green bean': 144,
#  'nonfat plain yogurt': 144,
#  'plum sauce': 144,
#  'cheddar cheese soup': 144,
#  'lime peel': 144,
#  'amarula cream liqueur': 144,
#  'sesame seed oil': 144,
#  'green peppercorn': 142,
#  'almond meal': 142,
#  'mushroom stem': 142,
#  'bisquick': 142,
#  'chestnut': 140,
#  'chicken thigh fillet': 140,
#  'garlic granule': 138,
#  'vegetable stock chicken': 138,
#  'pork belly': 136,
#  'cream coconut': 136,
#  'lager beer': 136,
#  'suet': 136,
#  'no salt tomato': 136,
#  'potato flake': 134,
#  'bulb garlic': 134,
#  'monterey jack cheddar cheese': 134,
#  'milk chocolate chip': 134,
#  'mini chocolate chip': 134,
#  'chicken cutlet': 134,
#  'tapioca flour': 132,
#  'pineapple tidbit': 132,
#  'halibut fillet': 130,
#  'yam': 128,
#  'mung bean sprout': 128,
#  'crab': 128,
#  'bread machine yeast': 128,
#  'wasabi': 128,
#  'colby cheese': 128,
#  'bread dough': 128,
#  'fire tomato': 128,
#  'baby shrimp': 126,
#  'coconut rum': 126,
#  'lobster': 126,
#  'stilton cheese': 126,
#  'lobster tail': 124,
#  'ouzo': 124,
#  'matzo meal': 124,
#  'ginger juice': 124,
#  'cranberry sauce': 122,
#  'muenster cheese': 122,
#  'chambord raspberry liquor': 122,
#  'chicken tenderloin': 120,
#  'baby potato': 120,
#  'celery root': 120,
#  'radicchio': 120,
#  'fusilli': 120,
#  'parmigiano': 120,
#  'sugar syrup': 118,
#  'trout': 118,
#  'wheat pastry flour': 118,
#  'turbinado sugar': 118,
#  'lobster meat': 118,
#  'milk powder': 116,
#  'pomegranate': 116,
#  'corn cob': 116,
#  'coffee powder': 116,
#  'chocolate square': 116,
#  'crisco': 116,
#  'pork fillet': 114,
#  'beefsteak tomato': 114,
#  'white bread flour': 114,
#  'frying chicken': 114,
#  'boston lettuce': 112,
#  'halloumi cheese': 112,
#  'tortellini': 112,
#  'pineapple ring': 112,
#  'spanish olive': 112,
#  'bulgar wheat': 112,
#  'butter margarine': 110,
#  'nonfat yogurt': 110,
#  'linguine pasta': 110,
#  'red snapper': 110,
#  'vanilla pod': 110,
#  'sweetcorn': 110,
#  'natural peanut butter': 108,
#  'ghee butter': 108,
#  'cake': 108,
#  'chocolate pudding mix': 108,
#  'cheese ravioli': 108,
#  'biscuit mix': 108,
#  'bouillon': 108,
#  'emmenthaler cheese': 108,
#  'lime leaf': 106,
#  'cabbage leaf': 106,
#  'hing': 106,
#  'custard powder': 106,
#  'heirloom tomato': 106,
#  'chicken part': 106,
#  'beef base': 106,
#  'creme de cacao': 106,
#  'potato traditional': 106,
#  'ha avocado': 104,
#  'bibb lettuce': 104,
#  'roquefort cheese': 104,
#  'ear corn': 104,
#  'camembert cheese': 104,
#  'lemon lime beverage': 104,
#  'sugar substitute': 104,
#  'cracker': 102,
#  'beef shank': 102,
#  'romaine lettuce heart': 102,
#  'frangelico': 102,
#  'raspberry vinegar': 100,
#  'focaccia bread': 98,
#  'pimento pepper': 98,
#  'vanilla pudding': 98,
#  'beef eye': 98,
#  'bulk pork sausage': 96,
#  'marmalade': 96,
#  'kumara': 96,
#  'head broccoli': 94,
#  'straw mushroom': 94,
#  'crawfish tail': 94,
#  'potato flour': 94,
#  'beef liver': 94,
#  'mushroom cap': 94,
#  'beef stock cube': 94,
#  'szechwan pepper': 94,
#  'no salt tomato sauce': 94,
#  'kielbasa sausage': 92,
#  'turkey sausage': 92,
#  'chocolate ice cream': 92,
#  'oriental sesame oil': 92,
#  'pineapple chunk juice': 90,
#  'pea pod': 90,
#  'head romaine lettuce': 90,
#  'grapefruit': 90,
#  'center pork chop': 90,
#  'pesto': 90,
#  'corn husk': 90,
#  'raspberry preserve': 90,
#  'espresso coffee': 90,
#  'salt cod fish': 90,
#  'muscovado sugar': 90,
#  'almond flour': 88,
#  'bulgur wheat': 88,
#  'turkey bacon': 88,
#  'wheat': 88,
#  'potato chip': 88,
#  'sazon goya': 88,
#  'custard': 88,
#  'anise': 88,
#  'masa harina flour': 88,
#  'cane sugar': 88,
#  'almond essence': 88,
#  'wheat pasta': 88,
#  'ricotta': 88,
#  'yellow lentil': 86,
#  'yellow potato': 86,
#  'catfish fillet': 86,
#  'neufchatel cheese': 86,
#  'corn niblets': 86,
#  'apple pie filling': 86,
#  'banana leaf': 86,
#  'mutton': 86,
#  'beef cube': 86,
#  'curd': 86,
#  'chocolate baking square': 86,
#  'pork shoulder roast': 84,
#  'honeydew melon': 84,
#  'cod fillet': 84,
#  'red radish': 84,
#  'gnocchi': 84,
#  'sandwich bun': 84,
#  'pork bean': 84,
#  'green plantain': 84,
#  'orange extract': 84,
#  'gluten flour': 84,
#  'grain bread': 84,
#  'tagliatelle pasta noodle': 84,
#  'tuna olive oil': 82,
#  'apricot nectar': 82,
#  'graham cracker crust': 82,
#  'oat bran': 82,
#  'corn muffin mix': 82,
#  'ham steak': 82,
#  'fillet': 82,
#  'bocconcini': 82,
#  'portabella mushroom cap': 82,
#  'grape juice': 82,
#  'tempeh': 80,
#  'wakame': 80,
#  'vanilla wafer': 80,
#  'buckwheat flour': 80,
#  'chicken base': 80,
#  'cracker crumb': 80,
#  'craisins': 80,
#  'aniseed': 80,
#  'ro tel tomato': 80,
#  'soybean': 78,
#  'chicken soup base': 78,
#  'nicoise olive': 78,
#  'butter lettuce': 78,
#  'pepperjack cheese': 78,
#  'wheat bran': 78,
#  'swede': 78,
#  'vital wheat gluten': 78,
#  'prosciutto ham': 78,
#  'pickle juice': 78,
#  'pernod': 78,
#  'rib beef': 78,
#  'brioche bread': 78,
#  'sausage meat': 78,
#  'rib eye steak': 76,
#  'lamb loin chop': 76,
#  'peach schnapps': 76,
#  'haddock fillet': 76,
#  'tomato basil pasta sauce': 76,
#  'stevia': 76,
#  'vegetable oil peanut': 76,
#  'orecchiette': 76,
#  'apricot half': 74,
#  'head lettuce': 74,
#  'panko bread crumb': 74,
#  'berry cranberry sauce': 74,
#  'dark chocolate chip': 74,
#  'chicken breast tender': 74,
#  'penne rigate': 74,
#  'ritz cracker': 74,
#  'consomme': 74,
#  'chocolate curl': 74,
#  'fontina': 74,
#  'beef bouillon powder': 72,
#  'mung bean': 72,
#  'tangerine': 72,
#  'green mango': 72,
#  'red cherry': 72,
#  'broccoli rabe': 72,
#  'ajwain': 72,
#  'chicken leg quarter': 70,
#  'portobello mushroom': 70,
#  'almond butter': 70,
#  'cheesecloth': 70,
#  'sugar cube': 70,
#  'herring fillet': 70,
#  'farina': 70,
#  'slab bacon': 70,
#  'sole fillet': 70,
#  'havarti cheese': 70,
#  'chicken fillet': 70,
#  'baking cocoa': 70,
#  'japanese soy sauce': 70,
#  'lamb meat': 68,
#  'garlic oil': 68,
#  'cherry pepper': 68,
#  'spiral pasta': 68,
#  'vegetable protein': 68,
#  'palm oil': 68,
#  'eggnog': 68,
#  'jarlsberg cheese': 68,
#  'mozzarella ball': 68,
#  'san marzano tomato': 68,
#  'bean thread noodle': 68,
#  'yeast cake': 68,
#  'quince': 66,
#  'pastry flour': 66,
#  'enoki mushroom': 66,
#  'onion seed': 66,
#  'mustard green': 66,
#  'sponge cake': 66,
#  'pretzel': 66,
#  'marshmallow creme': 66,
#  'trout fillet': 66,
#  'nutella': 66,
#  'german chocolate cake mix': 66,
#  'haddock': 64,
#  'red pepper paste': 64,
#  'strawberry preserve': 64,
#  'table cream': 64,
#  'sorrel': 64,
#  'seitan': 64,
#  'apple juice concentrate': 64,
#  'lamb fillet': 64,
#  'wheat couscous': 62,
#  'sardine': 62,
#  'edam cheese': 62,
#  'rice cereal': 62,
#  'red beet': 62,
#  'garlic chive': 62,
#  'white corn tortilla': 62,
#  'wheat flour tortilla': 62,
#  'chili without bean': 62,
#  'green leaf lettuce': 62,
#  'crepe': 62,
#  'cream sherry': 62,
#  'bread cube': 62,
#  'bulk sausage': 62,
#  'galliano': 62,
#  'pink grapefruit': 62,
#  'granola cereal': 62,
#  'bun': 62,
#  'kasseri cheese': 62,
#  'wheat penne': 62,
#  'clove garlic': 60,
#  'fajita seasoning': 60,
#  'chayotes': 60,
#  'garlic crouton': 60,
#  'asadero cheese': 60,
#  'mostaccioli pasta': 60,
#  'linguica sausage': 60,
#  'pumpernickel bread': 60,
#  'pork cutlet': 60,
#  'wheat bread crumb': 60,
#  'white wheat flour': 60,
#  'almond flavoring': 60,
#  'drambuie': 60,
#  'glutinous rice flour': 58,
#  'plum jam': 58,
#  'coffee bean': 58,
#  'naan bread': 58,
#  'seashell pasta': 58,
#  'pickling cucumber': 58,
#  'beef sausage': 58,
#  'sirloin beef': 58,
#  'chanterelle mushroom': 58,
#  'chocolate shaving': 58,
#  'buttermilk biscuit': 58,
#  'oleo': 58,
#  'porridge oat': 58,
#  'lamb stew meat': 56,
#  'turkey meat': 56,
#  'ear corn cob': 56,
#  'gorgonzola cheese': 56,
#  'rice milk': 56,
#  'yellow tomato': 56,
#  'tart shell': 56,
#  'fryer chicken': 56,
#  'bucatini pasta': 56,
#  'breakfast sausage': 56,
#  'crawfish': 56,
#  'bran cereal': 56,
#  'lemon curd': 56,
#  'cream cheese spread': 56,
#  'tomato jalapeno': 56,
#  'pre mozzarella cheese': 56,
#  'corn tortilla strip': 56,
#  'crust': 54,
#  'vegetable bouillon': 54,
#  'back bacon': 54,
#  'leaf lettuce': 54,
#  'pork neck': 54,
#  'bean paste': 54,
#  'steak seasoning': 54,
#  'beef marrow': 54,
#  'peach juice': 54,
#  'orange wedge': 54,
#  'tomato garlic': 54,
#  'cachaca': 54,
#  'cake yeast': 54,
#  'vegetable carrot': 54,
#  'pappardelle pasta': 54,
#  'mincemeat': 54,
#  'wheat lasagna noodle': 54,
#  'corn flake crumb': 54,
#  'flat bread': 54,
#  'roast pork': 54,
#  'spelt flour': 54,
#  'garlic flake': 54,
#  'carnation milk': 54,
#  'sirloin tip steak': 54,
#  'mesclun': 54,
#  'bean sauce': 52,
#  'green tea': 52,
#  'bosc pear': 52,
#  'mango juice': 52,
#  'cheddar monterey jack cheese': 52,
#  'coconut flour': 52,
#  'pork sausage link': 52,
#  'caramel': 52,
#  'oat flour': 52,
#  'digestive biscuit': 52,
#  'cornbread': 52,
#  'calamari': 52,
#  'apricot brandy': 52,
#  'peach preserve': 52,
#  'chocolate morsel': 52,
#  'chicken stock beef': 52,
#  'hamburger meat': 52,
#  'capellini': 52,
#  'plain white flour': 52,
#  'millet': 50,
#  'asian pear': 50,
#  'buttery cracker': 50,
#  'angel food cake': 50,
#  'agave syrup': 50,
#  'treacle': 50,
#  'greek feta cheese': 50,
#  'egg wash': 50,
#  'apple butter': 50,
#  'sumaq': 50,
#  'macaroni noodle': 50,
#  'orange section': 50,
#  'leaf thyme': 50,
#  'melon': 50,
#  'lamb cutlet': 50,
#  'cannellini': 50,
#  'pork mince': 50,
#  'snap pea': 50,
#  'mango pulp': 50,
#  'amaretti cooky': 50,
#  'jalapeno jack cheese': 50,
#  'lardons': 50,
#  'asian sesame oil': 48,
#  'thai peanut sauce': 48,
#  'soy flour': 48,
#  'pomegranate syrup': 48,
#  'white shoepeg corn': 48,
#  'guava': 48,
#  'citrus peel': 48,
#  'tangerine juice': 48,
#  ...}

# %%
df = pd.DataFrame.from_dict(ava_sorted_d, orient='index', columns=['Count'])
df.index.name = 'Ingredient'
df.reset_index(inplace=True)

df_sorted = df.sort_values('Count', ascending=False)
df_sorted
# Out:
#                Ingredient  Count
# 0                   onion  69096
# 1                  butter  54026
# 2            garlic clove  49786
# 3                   water  49546
# 4               olive oil  44782
# ...                   ...    ...
# 5052              tarhana      2
# 5053        lemon cordial      2
# 5054  cornichons cucumber      2
# 5055          milk cheese      2
# 7751                kamut      2
#
# [7752 rows x 2 columns]

# %%
for i in mapped_cf['RecipeDB Ingredient']:
    if i in df_sorted['Ingredient'].values:
        count_value = df_sorted.loc[df_sorted['Ingredient'] == i, 'Count'].values[0]
        mapped_cf.loc[mapped_cf['RecipeDB Ingredient'] == i, 'Count'] = count_value

# %%
mapped_cf
# Out:
#                      RecipeDB Ingredient   Sueatable Ingredient  Similarity  \
# 0                                  onion                  ONION    1.000001
# 1                                 butter                 BUTTER    1.000000
# 2                           garlic clove                 GARLIC    0.930919
# 3                                  water                  WATER    1.000000
# 4                              olive oil              OLIVE OIL    1.000000
# ...                                  ...                    ...         ...
# 7748                 dutch cocoa hershey     HAZELNUT CHOCOLATE    0.823729
# 7749              milk chocolate hershey         MILK CHOCOLATE    0.947778
# 7750  chocolate flavor crisp rice cereal  CHOCOLATE CREAM COOKY    0.818652
# 7751          chocolate ripple ice cream  CHOCOLATE CREAM COOKY    0.925916
# 7752               caramel topping syrup        CRANBERRY JUICE    0.852054
#
#         CF    Count
# 0     0.24  69096.0
# 1     9.90  54026.0
# 2     0.67  49786.0
# 3     0.49  49546.0
# 4     3.84  44782.0
# ...    ...      ...
# 7748  3.43      2.0
# 7749  3.60      2.0
# 7750  1.69      2.0
# 7751  1.69      2.0
# 7752  2.88      2.0
#
# [7753 rows x 5 columns]

# %%
mapped_cf.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Recipedb_mapped_ing_CF_count.csv', index=False)

# %%
mapped_cf['CF'].min()
# Out:
# 0.11

# %%
mapped_cf['CF'].max()
# Out:
# 27.72

# %%
mapped_cf['CF'].std()
# Out:
# 5.3985216829788545

# %%
mapped_cf['CF'].mean()
# Out:
# 4.137135302463562

# %% [markdown]
# **Ingredient count v/s its cf values**

# %%
# This plot shows the cf of less frequently used ingredients, more frequently used ingredients.

# %%
mapped_cf.sort_values('CF', ascending=False)
# Out:
#              RecipeDB Ingredient Sueatable Ingredient  Similarity     CF  \
# 4099  single strength beef broth       BEEF BONE FREE    0.840060  27.72
# 1210             vegetarian beef       BEEF BONE FREE    0.838977  27.72
# 6116         simple beef mixture       BEEF BONE FREE    0.855379  27.72
# 5884            clear beef stock       BEEF BONE FREE    0.815204  27.72
# 2554       vegetarian beef broth       BEEF BONE FREE    0.817879  27.72
# ...                          ...                  ...         ...    ...
# 1856                    absinthe               RADISH    0.839560   0.15
# 432                daikon radish               RADISH    0.816560   0.15
# 7035         bean cooking liquid          BEAN IN CAN    0.860088   0.11
# 1789               four bean mix          BEAN IN CAN    0.819926   0.11
# 6950             water from bean          BEAN IN CAN    0.880099   0.11
#
#       Count
# 4099    2.0
# 1210   32.0
# 6116    2.0
# 5884    2.0
# 2554    6.0
# ...     ...
# 1856   12.0
# 432   266.0
# 7035    2.0
# 1789   14.0
# 6950    2.0
#
# [7753 rows x 5 columns]

# %% [markdown]
# Bins of CF v/s Ingredient frequency

# %%
import pandas as pd

# Define the CF bins
cf_bins = range(0, 51, 2)  # Bins of width 10 starting from 0 up to 100

# Create a new column 'CF_Range' in the DataFrame
mapped_cf['CF_Range'] = pd.cut(mapped_cf['CF'], bins=cf_bins, right=False)

ing_counts = mapped_cf.groupby(['CF_Range']).size().reset_index(name='Count')

# Print the results
print("Ingredient counts for CF ranges:")
for i, row in ing_counts.iterrows():
    cf_range = row['CF_Range']
    count = row['Count']
    print(f"{cf_range}: {count}")
# Out:
# Ingredient counts for CF ranges:
# [0, 2): 3961
# [2, 4): 1839
# [4, 6): 316
# [6, 8): 212
# [8, 10): 410
# [10, 12): 278
# [12, 14): 7
# [14, 16): 45
# [16, 18): 243
# [18, 20): 435
# [20, 22): 0
# [22, 24): 0
# [24, 26): 0
# [26, 28): 7
# [28, 30): 0
# [30, 32): 0
# [32, 34): 0
# [34, 36): 0
# [36, 38): 0
# [38, 40): 0
# [40, 42): 0
# [42, 44): 0
# [44, 46): 0
# [46, 48): 0
# [48, 50): 0

# %%
plt.figure(figsize=(10,6)) 

# Convert 'CF_Range' to string
ing_counts['CF_Range'] = ing_counts['CF_Range'].astype(str)

# Calculate the normalized ingredient count
ing_counts['Normalized Count'] = ing_counts['Count'] / 10426


plt.plot(ing_counts['CF_Range'], ing_counts['Normalized Count'], marker='o')

# Set the x-axis and y-axis labels
plt.xlabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.ylabel("Number of ingredient", fontsize=12, fontname="Arial")
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()

# Show the plot
plt.show()

# %%
mapped_cf
# Out:
#                      RecipeDB Ingredient   Sueatable Ingredient  Similarity  \
# 0                                  onion                  ONION    1.000001
# 1                                 butter                 BUTTER    1.000000
# 2                           garlic clove                 GARLIC    0.930919
# 3                                  water                  WATER    1.000000
# 4                              olive oil              OLIVE OIL    1.000000
# ...                                  ...                    ...         ...
# 7748                 dutch cocoa hershey     HAZELNUT CHOCOLATE    0.823729
# 7749              milk chocolate hershey         MILK CHOCOLATE    0.947778
# 7750  chocolate flavor crisp rice cereal  CHOCOLATE CREAM COOKY    0.818652
# 7751          chocolate ripple ice cream  CHOCOLATE CREAM COOKY    0.925916
# 7752               caramel topping syrup        CRANBERRY JUICE    0.852054
#
#         CF    Count CF_Range
# 0     0.24  69096.0   [0, 2)
# 1     9.90  54026.0  [8, 10)
# 2     0.67  49786.0   [0, 2)
# 3     0.49  49546.0   [0, 2)
# 4     3.84  44782.0   [2, 4)
# ...    ...      ...      ...
# 7748  3.43      2.0   [2, 4)
# 7749  3.60      2.0   [2, 4)
# 7750  1.69      2.0   [0, 2)
# 7751  1.69      2.0   [0, 2)
# 7752  2.88      2.0   [2, 4)
#
# [7753 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

# Convert 'Count' and 'CF' columns to numeric (float) values
mapped_cf['Count'] = pd.to_numeric(mapped_cf['Count'], errors='coerce')
mapped_cf['CF'] = pd.to_numeric(mapped_cf['CF'], errors='coerce')

x1 = mapped_cf['Count']
y1 = mapped_cf['CF']

ax.scatter(x1, y1, color='blue')

ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.xlabel("Ingredients", fontsize=12, fontname="Arial")
plt.ylabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

# Convert 'Count' and 'CF' columns to numeric (float) values
mapped_cf['Count'] = pd.to_numeric(mapped_cf['Count'], errors='coerce')
mapped_cf['CF'] = pd.to_numeric(mapped_cf['CF'], errors='coerce')

x1 = mapped_cf['Count']
y1 = mapped_cf['CF']

ax.scatter(x1, y1, color='blue')
plt.xscale('log', base=10)

ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.xlabel("Ingredients", fontsize=12, fontname="Arial")
plt.ylabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

# Convert 'Count' and 'CF' columns to numeric (float) values
mapped_cf['Count'] = pd.to_numeric(mapped_cf['Count'], errors='coerce')
mapped_cf['CF'] = pd.to_numeric(mapped_cf['CF'], errors='coerce')

x1 = mapped_cf['Count']
y1 = mapped_cf['CF']

ax.scatter(x1, y1, color='blue')
plt.xscale('log', base=10)
plt.yscale('log', base=2)

ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.xlabel("Ingredients", fontsize=12, fontname="Arial")
plt.ylabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

# Convert 'Count' and 'CF' columns to numeric (float) values
mapped_cf['Count'] = pd.to_numeric(mapped_cf['Count'], errors='coerce')
mapped_cf['CF'] = pd.to_numeric(mapped_cf['CF'], errors='coerce')

x1 = mapped_cf['Count']
y1 = mapped_cf['CF']

ax.scatter(x1, y1, color='lightblue')
plt.xscale('log', base=10)

plt.yscale('log', base=2)

ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.xlabel("Ingredients", fontsize=12, fontname="Arial")
plt.ylabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()


# Add vertical lines on specific x-axis ticks
xticks_to_highlight = [100, 1000] 

yticks_to_highlight = [1, 4] 

for xtick in xticks_to_highlight:
    ax.axvline(x=xtick, color='dimgrey', linestyle='--')
    
for ytick in yticks_to_highlight:
    ax.axhline(y=ytick, color='dimgrey', linestyle='--')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Convert 'Count' and 'CF' columns to numeric (float) values
mapped_cf['Count'] = pd.to_numeric(mapped_cf['Count'], errors='coerce')
mapped_cf['CF'] = pd.to_numeric(mapped_cf['CF'], errors='coerce')

x1 = mapped_cf['Count']
y1 = mapped_cf['CF']

# Set colors for the scatter plot dots based on conditions
colors = []
for x, y in zip(x1, y1):
    if 0 <= x <= 100 and 0 <= y <= 1:
        colors.append('gold')
    elif 1000 < x <= 100000 and 0 <= y <= 1:
        colors.append('green')
    elif 0 <= x <= 100 and 4 <= y <= 50:
        colors.append('orange')
    elif 1000 < x <= 100000 and 4 <= y <= 50:
        colors.append('crimson')
    else:
        colors.append('skyblue')

plt.scatter(x1,y1, color=colors)
plt.xscale('log')
plt.yscale('log', base=2)

ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.xlabel("Popularity of food product", fontsize=18, fontname="Arial")
plt.ylabel("Carbon footprint", fontsize=18, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()

# Add vertical lines on specific x-axis ticks
xticks_to_highlight = [100, 1000] 

yticks_to_highlight = [1, 4] 

for xtick in xticks_to_highlight:
    ax.axvline(x=xtick, color='black', linestyle='--')
    
for ytick in yticks_to_highlight:
    ax.axhline(y=ytick, color='black', linestyle='--')

plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Popular_ing_cf_quad_color.jpeg", bbox_inches= 'tight', dpi=300)

plt.show()

# %%
red=[]
green=[]
gold=[]
orange=[]

for index, row in mapped_cf.iterrows():
    if 1000 < row['Count'] <= 100000 and 4 <= row['CF'] <= 50:
        red.append(row['RecipeDB Ingredient'])
    elif 0 <= row['Count'] <= 100 and 0 <= row['CF'] <= 1:
        gold.append(row['RecipeDB Ingredient'])
    elif 1000 < row['Count'] <= 100000 and 0 <= row['CF'] <= 1:
        green.append(row['RecipeDB Ingredient'])
    elif 0 <= row['Count'] <= 100 and 4 <= row['CF'] <= 50:
        orange.append(row['RecipeDB Ingredient'])

# %%
# ing_cond = pd.DataFrame()
# ing_cond['High Used and High CF ingredients'] = red
# ing_cond['High Used and Low CF ingredients'] = green
# ing_cond['Less Used and Low CF ingredients'] = gold
# ing_cond['Less Used and High CF ingredients'] = orange
# ing_cond

# %%
print("High Used and High CF ingredients:" , red)
print("High Used and Low CF ingredients:" , green)
print("Less Used and Low CF ingredients:" , gold)
print("Less Used and High CF ingredients:" , orange)
# Out:
# High Used and High CF ingredients: ['butter', 'milk', 'cinnamon', 'cream', 'parmesan cheese', 'beef', 'cheddar cheese', 'vanilla extract', 'mozzarella cheese', 'bacon', 'shallot', 'vanilla', 'shrimp', 'beef broth', 'feta cheese', 'cheese', 'pork', 'monterey jack cheese', 'ricotta cheese', 'whipping cream', 'chocolate', 'lamb', 'beef stock', 'chocolate chip', 'cottage cheese', 'sausage', 'prosciutto', 'provolone cheese', 'chorizo sausage']
# High Used and Low CF ingredients: ['onion', 'garlic clove', 'water', 'sugar', 'tomato', 'garlic', 'pepper', 'salt pepper', 'lemon juice', 'carrot', 'vegetable oil', 'ginger', 'potato', 'green onion', 'lemon', 'lime juice', 'garlic powder', 'celery', 'white wine', 'red bell pepper', 'coriander', 'green bell pepper', 'red pepper', 'turmeric', 'green pepper', 'sesame oil', 'scallion', 'zucchini', 'spinach', 'green chilies', 'breadcrumb', 'raisin', 'orange juice', 'cucumber', 'lime', 'coconut milk', 'yellow onion', 'avocado', 'lemon zest', 'sesame seed', 'pea', 'gingerroot', 'chive', 'onion powder', 'orange', 'apple', 'green bean', 'cabbage', 'eggplant', 'yeast', 'bell pepper', 'peanut', 'banana', 'caster sugar', 'plain flour', 'bread', 'garlic salt', 'lettuce', 'strawberry', 'plum tomato', 'chickpea', 'rom tomato', "confectioner ' sugar", 'vegetable broth', 'mango', 'pineapple', 'bean', 'orange zest', 'coriander leaf', 'kalamata olive', 'wheat flour', 'white wine vinegar', 'icing sugar', 'olive', 'fennel seed', 'broccoli', 'coriander seed', 'red chilies', 'vegetable stock', 'lemongrass', 'green olive', 'artichoke heart', 'apricot', 'coffee', 'oat', 'asparagus', 'date', 'cauliflower', 'green pea', 'pepper sauce', 'peppercorn', 'bread flour', 'sun tomato', 'broccoli floret', 'cranberry', 'confectioner sugar', 'bread crumb', 'lime wedge']
# Less Used and Low CF ingredients: ['raspberry vinegar', 'focaccia bread', 'pimento pepper', 'head broccoli', 'szechwan pepper', 'potato flour', 'oriental sesame oil', 'grapefruit', 'head romaine lettuce', 'muscovado sugar', 'espresso coffee', 'raspberry preserve', 'pea pod', 'potato chip', 'wheat', 'sazon goya', 'bulgur wheat', 'wheat pasta', 'cane sugar', 'banana leaf', 'curd', 'mutton', 'yellow potato', 'green plantain', 'red radish', 'honeydew melon', 'orange extract', 'grain bread', 'apricot nectar', 'oat bran', 'graham cracker crust', 'grape juice', 'ro tel tomato', 'cracker crumb', 'swede', 'vital wheat gluten', 'brioche bread', 'wheat bran', 'soybean', 'stevia', 'peach schnapps', 'apricot half', 'panko bread crumb', 'head lettuce', 'ritz cracker', 'tangerine', 'broccoli rabe', 'green mango', 'almond butter', 'sugar cube', 'eggnog', 'cherry pepper', 'vegetable protein', 'garlic oil', 'mustard green', 'onion seed', 'pretzel', 'strawberry preserve', 'red pepper paste', 'sorrel', 'wheat couscous', 'sardine', 'red beet', 'green leaf lettuce', 'bun', 'wheat flour tortilla', 'garlic chive', 'bread cube', 'wheat penne', 'clove garlic', 'wheat bread crumb', 'fajita seasoning', 'chayotes', 'garlic crouton', 'drambuie', 'pumpernickel bread', 'white wheat flour', 'pickling cucumber', 'naan bread', 'plum jam', 'coffee bean', 'lemon curd', 'tart shell', 'rice milk', 'vegetable bouillon', 'garlic flake', 'carnation milk', 'flat bread', 'peach juice', 'orange wedge', 'leaf lettuce', 'vegetable carrot', 'plain white flour', 'peach preserve', 'apricot brandy', 'bosc pear', 'green tea', 'calamari', 'caramel', 'coconut flour', 'asian pear', 'agave syrup', 'orange section', 'leaf thyme', 'snap pea', 'melon', 'millet', 'english pea', 'soy flour', 'baby onion', 'red miso', 'passata', 'pomegranate syrup', 'guava', 'asian sesame oil', 'citrus peel', 'green coriander', 'key lime', 'cassava', 'avocado oil', 'dripping', 'green creme de menthe', 'capicola', 'clementine', 'wheat breadcrumb', 'nuoc nam', 'loaf bread', 'fruit chutney', 'cherry juice', 'bartlett pear', 'celery heart', 'fennel leaf', 'red pepper powder', 'guava nectar', 'fuji apple', 'garlic butter', 'nutritional yeast flake', 'barley flour', 'coffee crystal', 'fennel powder', 'garlic olive oil', 'cream wheat', 'vegetable stock powder', 'wheat berry', 'garlic head', 'lemon twist', 'pasilla pepper', 'green banana', 'cranberry bean', 'red shallot', 'bing cherry', 'anjou pear', 'kirby cucumber', 'tamale', 'asparagus tip', 'graham wafer crumb', 'maui onion', 'nopales', 'fruit juice', 'grape jelly', 'wheat bread flour', 'broccoli stem', 'muesli', 'broccolini', 'gala apple', 'lingonberry', 'sparkling wine', 'egg wrapper', 'onion ring', 'sunflower seed oil', 'pineapple preserve', 'tart green apple', 'green asparagus', 'turnip green', 'onion juice', 'garlic bread', 'green tea powder', 'artichoke bottom', 'celery flake', 'frank red sauce', 'veal scallopini', 'wedge lime', 'yellow zucchini', 'toffee', 'baby eggplant', 'chicory lettuce', 'lovage', 'peach half', 'wondra flour', 'european cucumber', 'sesame paste', 'limeade', 'co lettuce', 'blackberry jam', 'curly endive lettuce', 'snail', 'coconut sugar', 'onion soup', 'purslane', 'sesame', 'potato reg', 'zucchini lengthwise', 'kohlrabi', 'cornichon', 'coffee creamer', "o'brien potato", 'garlic herb seasoning', 'fruit peel', 'red pesto sauce', 'garlic juice', 'guava paste', 'tangerine peel', 'lumpia skin', 'multigrain bread', 'anisette', 'recaito', 'onion paste', 'hibiscus flower', 'red bean paste', 'baby artichoke', 'white bread wheat', 'green cherry', 'mange tout pea', 'lemon balm', 'lard vegetable oil', 'biscuit dough', 'potato water', 'chestnut puree', 'soy milk', 'spinach fettuccine', 'mcintosh apple', 'peach nectar', 'creme de banane', 'cucumber lengthwise', 'yellow bean', 'manzanilla olive', 'guava juice', 'mandarin orange section', 'lemon leaf', 'espresso coffee powder', 'globe eggplant', 'pack pumpkin', 'tamarind chutney', 'wheat cracker', ...
# Less Used and High CF ingredients: ['beef eye', 'kumara', 'bulk pork sausage', 'beef stock cube', 'beef liver', 'kielbasa sausage', 'turkey sausage', 'center pork chop', 'turkey bacon', 'anise', 'neufchatel cheese', 'beef cube', 'catfish fillet', 'pork shoulder roast', 'gnocchi', 'pork bean', 'sandwich bun', 'tuna olive oil', 'ham steak', 'bocconcini', 'wakame', 'aniseed', 'vanilla wafer', 'craisins', 'rib beef', 'sausage meat', 'pernod', 'prosciutto ham', 'pepperjack cheese', 'orecchiette', 'rib eye steak', 'lamb loin chop', 'consomme', 'fontina', 'chocolate curl', 'penne rigate', 'ajwain', 'beef bouillon powder', 'sole fillet', 'slab bacon', 'farina', 'cheesecloth', 'havarti cheese', 'jarlsberg cheese', 'mozzarella ball', 'lamb meat', 'table cream', 'lamb fillet', 'kasseri cheese', 'galliano', 'edam cheese', 'cream sherry', 'crepe', 'bulk sausage', 'linguica sausage', 'pork cutlet', 'asadero cheese', 'sirloin beef', 'oleo', 'beef sausage', 'pre mozzarella cheese', 'breakfast sausage', 'gorgonzola cheese', 'lamb stew meat', 'cream cheese spread', 'crawfish', 'sirloin tip steak', 'roast pork', 'crust', 'back bacon', 'beef marrow', 'steak seasoning', 'pork neck', 'hamburger meat', 'chocolate morsel', 'pork sausage link', 'capellini', 'cheddar monterey jack cheese', 'pork mince', 'lamb cutlet', 'treacle', 'greek feta cheese', 'cannellini', 'jalapeno jack cheese', 'sumaq', 'lardons', 'tripe', 'cheese spread', 'mozzarella', 'taco cheese', 'tostada', 'stew beef chunk', 'ditalini', 'beef chuck steak', 'beef tongue', 'morel', 'chocolate bar', 'lamb steak', 'campari', 'octopus', 'boursin cheese', 'beef rump roast', 'fleur de sel', 'shoulder lamb chop', 'cheese food', 'italian pork sausage', 'non milk', 'cream milk', 'beef dripping', 'catfish', 'beef hot dog', 'vanilla flavoring', 'beef suet', 'mizithra cheese', 'pancetta bacon', 'sago', 'tuna oil', 'goat meat', 'venison steak', 'piri', 'bottom beef roast', 'kelp', 'pork stew meat', 'dulce de leche', 'pork butt roast', 'caraway', 'pectin', 'farro', 'frisee', 'stewing lamb', 'chunk tuna', 'beef oxtail', 'pork hock', 'cheese sauce', 'sazon goya coriander annatto', 'beef cube steak', 'pepper jack cheese', 'longhorn cheese', 'achiote', 'vegetarian beef', 'fillet catfish', 'pork leg', 'amaretti', 'squid ring', 'pouring cream', 'beef heart', 'beef stock broth', 'beef rump', 'albacore tuna', 'pork shank', 'crisp bacon', 'kangaroo fillet', 'sausage link', 'veal steak', 'beef loin steak', 'tuna brine', 'spicy pork sausage', 'paneer cheese', 'chevre cheese', 'pizza cheese', 'beef rib roast', 'vanilla powder', 'emeril essence', 'baby octopus', 'vanilla syrup', 'masoor dal', 'colby jack cheese', 'aioli', 'salad shrimp', 'beef tenderloin fillet', 'macaroni cheese', 'hijiki', 'meat beef', 'bacon strip', 'vegan parmesan cheese', 'beef shoulder', 'cheese whiz', 'lamb liver', 'chinese barbecue pork', 'khoya', 'wattleseed', 'campbell cheddar cheese soup', 'chocolate chunk', 'sofrito', 'log goat cheese', 'rub', 'saunf', 'mature cheddar cheese', 'beef tip', 'shortcut bacon', 'lamb rack', 'pork sirloin roast', 'chocolate wafer', 'cavatelli', 'rindless bacon', 'ahi tuna', 'sucanat', 'nacho cheese tortilla chip', 'lamb neck', 'lamb kidney', 'beef meat', 'cannelloni tube', 'garlic sausage', 'albacore tuna water', 'stir fry beef', 'lamb rib chop', 'loin lamb', 'nacho cheese soup', 'beef tip steak', 'wheel brie cheese', 'biscotti', 'pork sauce', 'cheese curd', 'taco meat', 'pork liver', 'parmesan romano cheese mix', 'creamy goat cheese', 'live lobster', 'kraft parmesan cheese', 'kefalotiri', 'macaroni cheese mix', 'bean pork', 'awamori', 'crab boil', 'beef tamale', 'beef cap', 'beef soup', 'shrimp stock', 'pork meat', 'beef neck', 'moisture part mozzarella cheese', 'comte cheese', 'creamy butter', 'beef blade roast', 'funghi porcini', 'deli beef', 'escargot', 'reblochon cheese', 'emeril', 'veal stock beef', 'pork broth', 'nacho cheese', 'roast beef gravy', 'cream whipping', 'turkey ham', 'jimmy dean sausage', ' ...

# %%
len(green)
# Out:
# 98

# %%
len(red)
# Out:
# 29

# %%
len(orange)
# Out:
# 1793

# %%
len(gold)
# Out:
# 2304

# %%
# red = 29
# green = 98
# gold = 2304
# orange= 1793
# blue = 3529
# total_ing_mapped = 7753


sizes = [29, 98, 2304, 1793, 3529]
labels = ['Red', 'Green', 'Gold', 'Orange', 'Blue']

# Define colors for the pie chart slices
colors = ['crimson', 'green', 'gold', 'orange', 'lightblue']
# print(sum(sizes))

# Calculate percentages
percentages = [size / sum(sizes) * 100 for size in sizes]

# Define properties for the outer circle border
outer_circle_border = {'linewidth': 1, 'edgecolor': 'black'}

# Create a pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, 
        wedgeprops=outer_circle_border, explode=(0.1, 0, 0, 0, 0))


# Set font properties
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.axis('equal')
plt.tight_layout()
plt.legend()

# plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Updated_Mansi/Plots/Fooditem_comparison.png", bbox_inches= 'tight', dpi=300)
# plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Updated_Mansi/Plots/Fooditem_comparison.svg", dpi=300)

plt.show()

# %% [markdown]
# # Table for red ingredients

# %%
red_df = pd.DataFrame()
red_df['RecipeDB Ingredient'] = red

# %%
red_df_m = pd.merge(red_df, mapped_cf, on='RecipeDB Ingredient')
red_df_m
# Out:
#      RecipeDB Ingredient Sueatable Ingredient  Similarity     CF    Count  \
# 0                 butter               BUTTER    1.000000   9.90  54026.0
# 1                   milk                CREAM    0.811914   5.34  29170.0
# 2               cinnamon              VANILLA    0.813387   4.30  19248.0
# 3                  cream                CREAM    1.000000   5.34  17160.0
# 4        parmesan cheese      CHEESE SEMIHARD    0.892052   8.65  15578.0
# 5                   beef       BEEF WITH BONE    0.873418  19.54  15348.0
# 6         cheddar cheese      CHEESE SEMIHARD    0.890534   8.65   8996.0
# 7        vanilla extract              VANILLA    0.913289   4.30   7912.0
# 8      mozzarella cheese      CHEESE SEMIHARD    0.858984   8.65   6936.0
# 9                  bacon                BACON    1.000000   4.03   6516.0
# 10               shallot                 HAKE    0.812584  10.12   5648.0
# 11               vanilla              VANILLA    1.000000   4.30   5548.0
# 12                shrimp               SHRIMP    1.000000  11.95   4888.0
# 13            beef broth       BEEF WITH BONE    0.887812  19.54   4604.0
# 14           feta cheese      CHEESE SEMIHARD    0.878201   8.65   4192.0
# 15                cheese               CHEESE    1.000000  11.87   3694.0
# 16                  pork            PORK NECK    0.963734   4.03   3610.0
# 17  monterey jack cheese      CHEESE SEMIHARD    0.818584   8.65   3182.0
# 18        ricotta cheese      CHEESE SEMIHARD    0.882184   8.65   2788.0
# 19        whipping cream                CREAM    0.870369   5.34   2466.0
# 20             chocolate            CHOCOLATE    1.000000   6.60   2098.0
# 21                  lamb       LAMB WITH BONE    0.814067  18.01   1880.0
# 22            beef stock       BEEF WITH BONE    0.837216  19.54   1840.0
# 23        chocolate chip            CHOCOLATE    0.933161   6.60   1470.0
# 24        cottage cheese               CHEESE    0.832171  11.87   1410.0
# 25               sausage         PORK SAUSAGE    0.876222  17.94   1138.0
# 26            prosciutto           STRACCHINO    0.841144   4.92   1114.0
# 27      provolone cheese               CHEESE    0.889644  11.87   1068.0
# 28       chorizo sausage         PORK SAUSAGE    0.858991  17.94   1060.0
#
#     CF_Range
# 0    [8, 10)
# 1     [4, 6)
# 2     [4, 6)
# 3     [4, 6)
# 4    [8, 10)
# 5   [18, 20)
# 6    [8, 10)
# 7     [4, 6)
# 8    [8, 10)
# 9     [4, 6)
# 10  [10, 12)
# 11    [4, 6)
# 12  [10, 12)
# 13  [18, 20)
# 14   [8, 10)
# 15  [10, 12)
# 16    [4, 6)
# 17   [8, 10)
# 18   [8, 10)
# 19    [4, 6)
# 20    [6, 8)
# 21  [18, 20)
# 22  [18, 20)
# 23    [6, 8)
# 24  [10, 12)
# 25  [16, 18)
# 26    [4, 6)
# 27  [10, 12)
# 28  [16, 18)

# %%
red_df_m.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Quad/Red_Ingredient.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Table for green ingredients

# %%
green_df = pd.DataFrame()
green_df['RecipeDB Ingredient'] = green

# %%
green_df_m = pd.merge(green_df, mapped_cf, on='RecipeDB Ingredient')
green_df_m
# Out:
#    RecipeDB Ingredient Sueatable Ingredient  Similarity    CF    Count  \
# 0                onion                ONION    1.000001  0.24  69096.0
# 1         garlic clove               GARLIC    0.930919  0.67  49786.0
# 2                water                WATER    1.000000  0.49  49546.0
# 3                sugar           BEET SUGAR    0.858168  0.89  40542.0
# 4               tomato               TOMATO    1.000000  0.48  33250.0
# ..                 ...                  ...         ...   ...      ...
# 93     broccoli floret             BROCCOLI    0.827768  0.67   1078.0
# 94           cranberry            CRANBERRY    1.000000  0.90   1074.0
# 95  confectioner sugar           BEET SUGAR    0.863485  0.89   1046.0
# 96         bread crumb    BREAD MULTICEREAL    0.883305  0.70   1046.0
# 97          lime wedge                 LIME    0.884217  0.22   1024.0
#
#    CF_Range
# 0    [0, 2)
# 1    [0, 2)
# 2    [0, 2)
# 3    [0, 2)
# 4    [0, 2)
# ..      ...
# 93   [0, 2)
# 94   [0, 2)
# 95   [0, 2)
# 96   [0, 2)
# 97   [0, 2)
#
# [98 rows x 6 columns]

# %%
green_df_m.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Quad/Green_Ingredient.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Table for orange ingredients

# %%
orange_df = pd.DataFrame()
orange_df['RecipeDB Ingredient'] = orange

# %%
orange_df_m = pd.merge(orange_df, mapped_cf, on='RecipeDB Ingredient')
orange_df_m
# Out:
#                  RecipeDB Ingredient Sueatable Ingredient  Similarity     CF  \
# 0                           beef eye       BEEF WITH BONE    0.899462  19.54
# 1                             kumara                 HAKE    0.815513  10.12
# 2                  bulk pork sausage         PORK SAUSAGE    0.949255  17.94
# 3                    beef stock cube       BEEF WITH BONE    0.828140  19.54
# 4                         beef liver       BEEF WITH BONE    0.901181  19.54
# ...                              ...                  ...         ...    ...
# 1788             pepper beef sausage         PORK SAUSAGE    0.860281  17.94
# 1789                cream preferably                CREAM    0.905940   5.34
# 1790  violet crumble chocolate candy     ALMOND CHOCOLATE    0.852443   4.80
# 1791                      grumichama                 HAKE    0.844618  10.12
# 1792                     cheese tart      CHEESE SEMIHARD    0.909929   8.65
#
#       Count  CF_Range
# 0      98.0  [18, 20)
# 1      96.0  [10, 12)
# 2      96.0  [16, 18)
# 3      94.0  [18, 20)
# 4      94.0  [18, 20)
# ...     ...       ...
# 1788    2.0  [16, 18)
# 1789    2.0    [4, 6)
# 1790    2.0    [4, 6)
# 1791    2.0  [10, 12)
# 1792    2.0   [8, 10)
#
# [1793 rows x 6 columns]

# %%
orange_df_m.to_csv('D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Data/Mapped/Quad/Orange_Ingredient.csv', encoding='utf-8', index=False)

# %%
low_orange=[]
for index, row in mapped_cf.iterrows():
    if 0 < row['Count'] <= 2 and 18 <= row['CF'] <= 30 :
        low_orange.append(row['RecipeDB Ingredient'])

# %%
len(low_orange)
# Out:
# 225

# %%
low_orange=[]
for index, row in mapped_cf.iterrows():
    if 0 < row['Count'] <= 2 and 19 <= row['CF'] <= 30 :
        low_orange.append(row['RecipeDB Ingredient'])
        
len(low_orange)
# Out:
# 194

# %%
low_orange=[]
for index, row in mapped_cf.iterrows():
    if 0 < row['Count'] <= 2 and 20 <= row['CF'] <= 30 :
        low_orange.append(row['RecipeDB Ingredient'])
        
len(low_orange)
print(low_orange)
# Out:
# ['single strength beef broth', 'clear beef stock', 'simple beef mixture', 'beef stock neat']

# %% [markdown]
# # TOP 100 ingredients

# %%
#exact matching

top_exa_ingredients = list(exa_ava_sorted_d.keys())[:100]
# top_ava_ingredients

top_ingredients = list(sorted_d.keys())[:100]
# top_ingredients

exa_common_ingredients = set(top_exa_ingredients).intersection(top_ingredients)
print("Count of available ingredients:", len(exa_common_ingredients))
# Out:
# Count of available ingredients: 28

# %%
#substring matching

top_ava_ingredients = list(ava_sorted_d.keys())
top_ingredients = list(sorted_d.keys())[:100]

common_ingredients = set(top_ava_ingredients).intersection(top_ingredients)

print("Count of available ingredients:", len(common_ingredients))
# Out:
# Count of available ingredients: 71

# %%
left_unmapped = list(set(top_ingredients) - set(common_ingredients))
left_unmapped
# Out:
# ['bay leaf',
#  'salt',
#  'clove',
#  'red onion',
#  'worcestershire sauce',
#  'canola oil',
#  'jalapeno pepper',
#  'kosher salt',
#  'sea salt',
#  'parsley',
#  'salsa',
#  'heavy cream',
#  'extra virgin olive oil',
#  'brown sugar',
#  'thyme',
#  'black bean',
#  'paprika',
#  'baking soda',
#  'cayenne pepper',
#  'oil',
#  'baking powder',
#  'oregano',
#  'chili powder',
#  'black pepper',
#  'white sugar',
#  'cilantro',
#  'salt black pepper',
#  'red pepper flake',
#  'basil']

# %%
total_mapped = pd.read_csv("D:/IIITD/Mansi_Thesis_Research/Foodprint/Carbon_Footprint_July23/Data/Mapped/bert_nli_recipedb_sueat_mapping.csv")

# %%
# Assuming you have the common ingredients as a list of strings
common_ingredients = list(left_unmapped)

# Create a DataFrame with the common ingredients
common_ingredients_df = pd.DataFrame({'RecipeDB Ingredient': left_unmapped})

# Merge mapped_cf dataset with the common_ingredients_df DataFrame
unmapped_100 = pd.merge(total_mapped, common_ingredients_df, on='RecipeDB Ingredient')

unmapped_100.sort_values('Similarity', ascending=False)
# Out:
#     Unnamed: 0     RecipeDB Ingredient Sueatable Ingredient  Similarity
# 17          53        red pepper flake           RED CHILLI    0.805939
# 2           15                 parsley               LENTIL    0.797203
# 19          64                   clove                PESTO    0.796132
# 25          89              canola oil            OLIVE OIL    0.790340
# 16          52          cayenne pepper               PEPPER    0.789373
# 14          47             white sugar           WINE WHITE    0.785960
# 15          48               red onion           RED CHILLI    0.782667
# 13          45                   thyme               RADISH    0.779701
# 26          91                sea salt              SEABASS    0.776494
# 0            0                    salt               PEPPER    0.771985
# 5           31             brown sugar           CANE SUGAR    0.757852
# 6           32                     oil            OLIVE OIL    0.749397
# 7           33                   basil                LEMON    0.749105
# 23          78             baking soda       FLAVOR CRACKER    0.747606
# 22          75             heavy cream                CREAM    0.738696
# 8           38  extra virgin olive oil            OLIVE OIL    0.738032
# 3           24                cilantro               CARROB    0.731755
# 10          41                 paprika            MARGARINE    0.730842
# 12          43            chili powder               PEPPER    0.721625
# 20          67    worcestershire sauce             CUCUMBER    0.719867
# 27          97         jalapeno pepper               PEPPER    0.718689
# 9           39           baking powder           BEET SUGAR    0.716964
# 11          42                bay leaf              SEABASS    0.714555
# 1            9            black pepper       DARK CHOCOLATE    0.699208
# 18          60       salt black pepper               PEPPER    0.691224
# 21          70             kosher salt           MAYONNAISE    0.673425
# 28          99              black bean                 BEAN    0.660380
# 4           28                 oregano         GRAHAM FLOUR    0.630695
# 24          86                   salsa                 TUNA    0.618299

# %% [markdown]
# **Top 100 recipedb ingredients.
# Ingredients exact match is 28
# Ingredients substring match is 71**

# %%
# Assuming you have the common ingredients as a list of strings
common_ingredients = set(top_ava_ingredients).intersection(top_ingredients)
common_ingredients = list(common_ingredients)

# Create a DataFrame with the common ingredients
common_ingredients_df = pd.DataFrame({'RecipeDB Ingredient': common_ingredients})

# Merge mapped_cf dataset with the common_ingredients_df DataFrame
mapped_100 = pd.merge(mapped_cf, common_ingredients_df, on='RecipeDB Ingredient')

mapped_100
# Out:
#    RecipeDB Ingredient Sueatable Ingredient  Similarity     CF    Count  \
# 0                onion                ONION    1.000001   0.24  69096.0
# 1               butter               BUTTER    1.000000   9.90  54026.0
# 2         garlic clove               GARLIC    0.930919   0.67  49786.0
# 3                water                WATER    1.000000   0.49  49546.0
# 4            olive oil            OLIVE OIL    1.000000   3.84  44782.0
# ..                 ...                  ...         ...    ...      ...
# 66        orange juice         ORANGE JUICE    1.000000   0.62   4654.0
# 67            red wine             WINE RED    0.976454   1.02   4632.0
# 68            cucumber             CUCUMBER    1.000000   0.32   4614.0
# 69          beef broth       BEEF WITH BONE    0.887812  19.54   4604.0
# 70                lime                 LIME    1.000000   0.22   4562.0
#
#     CF_Range
# 0     [0, 2)
# 1    [8, 10)
# 2     [0, 2)
# 3     [0, 2)
# 4     [2, 4)
# ..       ...
# 66    [0, 2)
# 67    [0, 2)
# 68    [0, 2)
# 69  [18, 20)
# 70    [0, 2)
#
# [71 rows x 6 columns]

# %%
# Sort the dataframe by CF values in descending order
mapped_100_sorted = mapped_100.sort_values(by='CF', ascending=False)

fig, ax = plt.subplots(figsize=(14, 6))

plt.plot(mapped_100_sorted['RecipeDB Ingredient'], mapped_100_sorted['CF'], marker="o", color='cornflowerblue')

# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)

plt.ylabel("Carbon footprint", fontsize=12, fontname="Arial")
plt.grid(False)

plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.margins(x=0.01, tight=True)

plt.savefig("D:/IIITD/Mansi_Thesis_Research/Foodprint/Github-SustainableFoodDB/Plots/Ingredient_analysis/Top_100_recipedb_ing_cf.jpeg", bbox_inches= 'tight', dpi=300)

plt.show()
